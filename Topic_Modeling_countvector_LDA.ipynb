# %%
#import liobrary
import pandas as pd

# %%
#read Text File
df = pd.read_csv("mabel.txt",header=None,on_bad_lines='skip',encoding='utf8')

# %%
#remove unwanted first row
df=df.drop(0)
#sets column names
df.columns=['Date','Chat']
#split the chat message till '-'
Message=df["Chat"].str.split("-",n=1,expand=True)
#Assign a name to 0th column
df["Time"]=Message[0]
##split the chat message till ':'
Message1=Message[1].str.split(":",n=1,expand=True)
df["Name"]=Message1[0]
df["Chat"]=Message1[1]
#Now the dataset has 4 columns
df=df[["Date","Time","Name","Chat"]]
df
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# 22  05/12/19    4:44 pm    Mabel Infoziant
# 23  05/12/19    4:48 pm                AR❤
# 24  05/12/19    8:07 pm                AR❤
# 25  08/12/19   10:45 pm    Mabel Infoziant
# 26  08/12/19   11:52 pm                AR❤
# 27  08/12/19   11:55 pm                AR❤
# 28  09/12/19   12:09 pm                AR❤
# 29  09/12/19   12:13 pm    Mabel Infoziant
# 30  09/12/19   12:23 pm    Mabel Infoziant
# 31  09/12/19   12:25 pm                AR❤
# 32  09/12/19   12:26 pm                AR❤
# 33  09/12/19   12:26 pm                AR❤
# 34  09/12/19   12:28 pm                AR❤
# 35  09/12/19   12:28 pm                AR❤
# 36  09/12/19   12:29 pm                AR❤
# 37  09/12/19   12:41 pm    Mabel Infoziant
# 38  09/12/19   12:42 pm                AR❤
# 39  10/12/19    7:59 am    Mabel Infoziant
# 40  10/12/19    8:00 am    Mabel Infoziant
# 41  10/12/19    8:55 am                AR❤
# 42  12/12/19    2:26 pm    Mabel Infoziant
# 43  15/12/19    8:22 pm                AR❤
# 44  15/12/19    8:40 pm    Mabel Infoziant
# 45  15/12/19    8:40 pm                AR❤
# 46  18/12/19    3:09 pm                AR❤
# 47  18/12/19    3:09 pm                AR❤
# 48  18/12/19    3:11 pm    Mabel Infoziant
# 49  18/12/19    3:11 pm    Mabel Infoziant
# 50  18/12/19    3:12 pm                AR❤
#
#                                                  Chat
# 1                      Hi this is Mabel we just spoke
# 2                               What’s your full name
# 3                                      Ramisha Rani K
# 4                                                  Ok
# 5                              ramisharanik@gmail.com
# 6                                      Your email Id?
# 7                                             Yes Mam
# 8      I will send 2 abstracts for u to start working
# 9                                            Yeah mam
# 10                   Give me the list that u have too
# 11   Send me cbe office address and phone number I...
# 12    Yeah Mam within Evening I will forward you mam.
# 13   Tomorrow I have to visit the office.yet not I...
# 14                                                 ok
# 15   send the details of office location once u ge...
# 16   Sure mam. Soon I will share details with you mam
# 17   I have read the Abstract mam. We can do mam. ...
# 18   I think Vignesh has the data set will ask him...
# 19                          I have sent the abstracts
# 20                                             Ok mam
# 21   I have read both the abstract mam. We can do ...
# 22   Yes we need to ya about amount and all other ...
# 23                                          Sure mam.
# 24                                  Shall I call mam?
# 25         Hi I was at church couldn’t take your call
# 26                                         It's k mam
# 27   Just to know the tomorrow plan mam.will see t...
# 28                    Mam can u send Vignesh number??
# 29           Vignesh ML Infoziant.vcf (file attached)
# 30                           I was in a meeting sorry
# 31                                    Can I cal u mam
# 32   Waiting for u r finalization of rates for our...
# 33   If we finiliaze I can work with full involvem...
# 34   So what ever may be ..if you think your are c...
# 35                           You deleted this message
# 36                                     Do the needful
# 37   No ma please hold I am in a hot meeting with ...
# 38                                     Ok mam thank u
# 39   Ramisha we need to talk today i will call u a...
# 40     Be ready to discuss about the ML titles u have
# 41                                           Okay mam
# 42                                                 ok
# 43                                    Mam are u free?
# 44   Am at church can call very late or tomorrow only
# 45   Kk mam. I will ask Arun brother. Small doubt ...
# 46                                             Hi mam
# 47                                   Any updates mam?
# 48     U might have to start on the WhatsApp analysis
# 49            There is one project that got committed
# 50                                           Kk mam👍🏻

# %%
y#import library for preprocess technique(CountVector)
from sklearn.feature_extraction.text import CountVectorizer
#import library for topic_modeling_algorithm  LDA
from sklearn.decomposition import LatentDirichletAllocation

# %%
#Model creation for count vector
count_vector= CountVectorizer(max_df=0.95,min_df=2,stop_words='english')
dtm=count_vector.fit_transform(df["Chat"])

# %%
##Model creation for LDA
lda_model=LatentDirichletAllocation(n_components=2,random_state=42)
lda_model.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
#gives topic proabilties
topic_results=lda_model.transform(dtm)
#select best topic per document
df["Topic"]=topic_results.argmax(axis=1)

# %%
#index=>topic number(0,1,2),topic=>weights(proability) of words in that topic
#Row=one topic,column=>proability of paticular word
for index,topic in enumerate(lda_model.components_):
    #gives all words in our vocabulary 
    #argsort return index of 10 highest proability elements in ascendind order
    results=([count_vector.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print(results)
# Out:
# ['meeting', 'ml', 'start', 'abstracts', 'church', 'office', 'send', 'vignesh', 'hi', 'tomorrow']
# ['abstract', 'read', 'ask', 'share', 'send', 'number', 'need', 'details', 'ok', 'mam']

# %%
df
# Out:
#         Date        Time              Name  \
# 0   05/12/19    1:42 pm    Mabel Infoziant
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm                AR❤
# 3   05/12/19    1:42 pm    Mabel Infoziant
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:43 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm                AR❤
# 7   05/12/19    1:43 pm    Mabel Infoziant
# 8   05/12/19    1:43 pm                AR❤
# 9   05/12/19    1:43 pm    Mabel Infoziant
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:44 pm                AR❤
# 12  05/12/19    1:45 pm                AR❤
# 13  05/12/19    1:48 pm    Mabel Infoziant
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:49 pm                AR❤
# 16  05/12/19    2:00 pm                AR❤
# 17  05/12/19    2:04 pm    Mabel Infoziant
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:06 pm                AR❤
# 20  05/12/19    2:07 pm                AR❤
# 21  05/12/19    4:44 pm    Mabel Infoziant
# 22  05/12/19    4:48 pm                AR❤
# 23  05/12/19    8:07 pm                AR❤
# 24  08/12/19   10:45 pm    Mabel Infoziant
# 25  08/12/19   11:52 pm                AR❤
# 26  08/12/19   11:55 pm                AR❤
# 27  09/12/19   12:09 pm                AR❤
# 28  09/12/19   12:13 pm    Mabel Infoziant
# 29  09/12/19   12:23 pm    Mabel Infoziant
# 30  09/12/19   12:25 pm                AR❤
# 31  09/12/19   12:26 pm                AR❤
# 32  09/12/19   12:26 pm                AR❤
# 33  09/12/19   12:28 pm                AR❤
# 34  09/12/19   12:28 pm                AR❤
# 35  09/12/19   12:29 pm                AR❤
# 36  09/12/19   12:41 pm    Mabel Infoziant
# 37  09/12/19   12:42 pm                AR❤
# 38  10/12/19    7:59 am    Mabel Infoziant
# 39  10/12/19    8:00 am    Mabel Infoziant
# 40  10/12/19    8:55 am                AR❤
# 41  12/12/19    2:26 pm    Mabel Infoziant
# 42  15/12/19    8:22 pm                AR❤
# 43  15/12/19    8:40 pm    Mabel Infoziant
# 44  15/12/19    8:40 pm                AR❤
# 45  18/12/19    3:09 pm                AR❤
# 46  18/12/19    3:09 pm                AR❤
# 47  18/12/19    3:11 pm    Mabel Infoziant
# 48  18/12/19    3:11 pm    Mabel Infoziant
# 49  18/12/19    3:12 pm                AR❤
#
#                                                  Chat  Topic
# 0                      Hi this is Mabel we just spoke      0
# 1                               What’s your full name      0
# 2                                      Ramisha Rani K      1
# 3                                                  Ok      1
# 4                              ramisharanik@gmail.com      0
# 5                                      Your email Id?      0
# 6                                             Yes Mam      1
# 7      I will send 2 abstracts for u to start working      0
# 8                                            Yeah mam      1
# 9                    Give me the list that u have too      0
# 10   Send me cbe office address and phone number I...      1
# 11    Yeah Mam within Evening I will forward you mam.      1
# 12   Tomorrow I have to visit the office.yet not I...      0
# 13                                                 ok      1
# 14   send the details of office location once u ge...      1
# 15   Sure mam. Soon I will share details with you mam      1
# 16   I have read the Abstract mam. We can do mam. ...      1
# 17   I think Vignesh has the data set will ask him...      0
# 18                          I have sent the abstracts      0
# 19                                             Ok mam      1
# 20   I have read both the abstract mam. We can do ...      1
# 21   Yes we need to ya about amount and all other ...      1
# 22                                          Sure mam.      1
# 23                                  Shall I call mam?      1
# 24         Hi I was at church couldn’t take your call      0
# 25                                         It's k mam      1
# 26   Just to know the tomorrow plan mam.will see t...      0
# 27                    Mam can u send Vignesh number??      1
# 28           Vignesh ML Infoziant.vcf (file attached)      0
# 29                           I was in a meeting sorry      0
# 30                                    Can I cal u mam      1
# 31   Waiting for u r finalization of rates for our...      0
# 32   If we finiliaze I can work with full involvem...      0
# 33   So what ever may be ..if you think your are c...      0
# 34                           You deleted this message      0
# 35                                     Do the needful      0
# 36   No ma please hold I am in a hot meeting with ...      0
# 37                                     Ok mam thank u      1
# 38   Ramisha we need to talk today i will call u a...      1
# 39     Be ready to discuss about the ML titles u have      0
# 40                                           Okay mam      1
# 41                                                 ok      1
# 42                                    Mam are u free?      1
# 43   Am at church can call very late or tomorrow only      0
# 44   Kk mam. I will ask Arun brother. Small doubt ...      1
# 45                                             Hi mam      1
# 46                                   Any updates mam?      1
# 47     U might have to start on the WhatsApp analysis      0
# 48            There is one project that got committed      0
# 49                                           Kk mam👍🏻      1

# %%
df["Topic"].value_counts()
# Out:
# Topic
# 1    27
# 0    23
# Name: count, dtype: int64

# %%
#!pip install wordCloud

# %%
dataset=df

# %%
#create visual words
from wordcloud import WordCloud
#remove stop words
from nltk.corpus import stopwords
#nltk means natual language toolkit
import nltk
#disply image
import matplotlib.pyplot as plt
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jegat\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#collect all chat text
comment_words = []
stoplist = stopwords.words('english')
#Remove unwanted words
stoplist.extend(['omitted', 'voice','missed','call','video','deleted','media','message'])
wordcloudss="This function saves image"
dataset.index=range(dataset.shape[0])
for i in range(1,len(dataset)): 
    comment_words.append(dataset['Chat'][i])
    #combine all msg into one big text
    vv=" ".join(comment_words)          
    #wordcount=>howmany times the word appear
    #Bigger values are clear,higher resolution.Displys most frequented words  BIGGER.
    #SMALLER words =Less Frequent
    wordcloud = WordCloud(width = 800, height = 800, 
                                background_color ='white', 
                                      stopwords = stoplist, 
                                      min_font_size = 10).generate(vv)         
plt.figure(figsize = (9, 7), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off") 
plt.tight_layout(pad = 0) 
#Save the image
plt.savefig('wordcloud.PNG')
plt.show() 
print("Successfully created")
wordcloudss="This function saves image"
# Out:
# Successfully created
